# %%
import numpy as np
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.spatial import KDTree
from geopy.distance import geodesic 

import pickle
from pprint import pprint

# %%
import sys  
sys.path.insert(0, '/Users/juliaortheden/africa_poverty_clean/utils/')

import geoplot

# %%
# !ls
# Out:
# 0_export_tfrecords.ipynb       __pycache__
# 1_process_tfrecords.ipynb      create_folds.py
# 2_create_incountry_folds.ipynb ee_utils.py
# 3_download_gadm_shapefiles.sh  helper.py
# SurveyExploration.ipynb

# %%
# !apt-get install libproj-dev proj-data proj-bin
# !apt-get install libgeos-dev
# !pip install cython
# !pip install cartopy
# Out:
# /bin/sh: apt-get: command not found
# /bin/sh: apt-get: command not found
# Requirement already satisfied: cython in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (0.29.13)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/juliaortheden/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: cartopy in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (0.18.0)
# Requirement already satisfied: six>=1.3.0 in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (from cartopy) (1.15.0)
# Requirement already satisfied: shapely>=1.5.6 in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (from cartopy) (1.7.1)
# Requirement already satisfied: pyshp>=1.1.4 in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (from cartopy) (2.1.3)
# Requirement already satisfied: setuptools>=0.7.2 in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (from cartopy) (45.2.0)
# Requirement already satisfied: numpy>=1.10 in /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages (from cartopy) (1.19.5)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/juliaortheden/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !ls
# Out:
# 0_export_tfrecords.ipynb       __pycache__
# 1_process_tfrecords.ipynb      create_folds.py
# 2_create_incountry_folds.ipynb ee_utils.py
# 3_download_gadm_shapefiles.sh  helper.py
# SurveyExploration.ipynb

# %%
#clusters_df = pd.read_csv('data/dhs_clusters.csv')

# %%
clusters_df
# Out:
#         country  year        lat        lon  GID_1    GID_2  wealthpooled  \
# 0        angola  2011 -12.350257  13.534922  AGO.2  AGO.2.9      2.595618
# 1        angola  2011 -12.360865  13.551494  AGO.2  AGO.2.9      2.209620
# 2        angola  2011 -12.613421  13.413085  AGO.2  AGO.2.3      0.906469
# 3        angola  2011 -12.581454  13.397711  AGO.2  AGO.2.3      1.105359
# 4        angola  2011 -12.578135  13.418748  AGO.2  AGO.2.3      1.879344
# ...         ...   ...        ...        ...    ...      ...           ...
# 19042  zimbabwe  2015 -17.915288  31.156115  ZWE.2  ZWE.2.1      0.237659
# 19043  zimbabwe  2015 -18.379501  31.872287  ZWE.3  ZWE.3.4      0.492502
# 19044  zimbabwe  2015 -16.660612  29.850649  ZWE.6  ZWE.6.2     -0.088922
# 19045  zimbabwe  2015 -17.914251  30.956975  ZWE.2  ZWE.2.1      1.613829
# 19046  zimbabwe  2015 -17.859114  31.797626  ZWE.5  ZWE.5.5      0.130854
#
#        households  urban_rural
# 0              36            1
# 1              32            1
# 2              36            1
# 3              35            1
# 4              37            1
# ...           ...          ...
# 19042          24            1
# 19043          25            0
# 19044          28            0
# 19045          25            1
# 19046          28            0
#
# [19047 rows x 9 columns]

# %%
df = pd.read_csv('data/aggregated_survey_data.csv')

# %%
adels_df = pd.read_csv('data/poverty_data.csv')

# %%
adels_df[adels_df['ClusterID'] == 'AO.Bengo.71.135']
# Out:
#      Unnamed: 0       PersonID.unique  country.code.ISO.3166.alpha.3  \
# 0             1   AO.Bengo.71.135.1.1                             24
# 1             2  AO.Bengo.71.135.1.10                             24
# 2             3  AO.Bengo.71.135.1.11                             24
# 3             4  AO.Bengo.71.135.1.12                             24
# 4             5  AO.Bengo.71.135.1.13                             24
# ..          ...                   ...                            ...
# 122         123   AO.Bengo.71.135.9.2                             24
# 123         124   AO.Bengo.71.135.9.3                             24
# 124         125   AO.Bengo.71.135.9.4                             24
# 125         126   AO.Bengo.71.135.9.5                             24
# 126         127   AO.Bengo.71.135.9.6                             24
#
#      RegionID        ClusterID        HouseholdID country  sample.weight  \
# 0    AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.1  Angola         274457
# 1    AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.1  Angola         274457
# 2    AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.1  Angola         274457
# 3    AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.1  Angola         274457
# 4    AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.1  Angola         274457
# ..        ...              ...                ...     ...            ...
# 122  AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.9  Angola         274457
# 123  AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.9  Angola         274457
# 124  AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.9  Angola         274457
# 125  AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.9  Angola         274457
# 126  AO.Bengo  AO.Bengo.71.135  AO.Bengo.71.135.9  Angola         274457
#
#      year.of.interview  month.of.interview       lat        lon     wealth
# 0                 2015                  11 -8.589805  13.640789  60.393383
# 1                 2015                  11 -8.589805  13.640789  60.393383
# 2                 2015                  11 -8.589805  13.640789  60.393383
# 3                 2015                  11 -8.589805  13.640789  60.393383
# 4                 2015                  11 -8.589805  13.640789  60.393383
# ..                 ...                 ...       ...        ...        ...
# 122               2015                  11 -8.589805  13.640789  57.147865
# 123               2015                  11 -8.589805  13.640789  57.147865
# 124               2015                  11 -8.589805  13.640789  57.147865
# 125               2015                  11 -8.589805  13.640789  57.147865
# 126               2015                  11 -8.589805  13.640789  57.147865
#
# [127 rows x 13 columns]

# %%
df['ClusterID']= adels_df['ClusterID'].unique()
print(adels_df.groupby(['ClusterID'])['year.of.interview'].mean())
# Out:
# ClusterID
# AO.Bengo.71.135      2015.0
# AO.Bengo.71.158      2016.0
# AO.Bengo.71.169      2015.0
# AO.Bengo.71.203      2016.0
# AO.Bengo.71.208      2015.0
#                       ...
# ZW.Midlands.72.37    2015.0
# ZW.Midlands.72.52    2015.0
# ZW.Midlands.72.69    2015.0
# ZW.Midlands.72.91    2015.0
# ZW.Midlands.72.97    2015.0
# Name: year.of.interview, Length: 30868, dtype: float64

# %%
df = pd.DataFrame(columns=['country', 'ClusterID', 'households', 'lat', 'lon', 'wealth_pooled'])
def create_new_data(old_df, df):
    df['ClusterID']= old_df['ClusterID'].unique()  
    df['wealth_pooled'] = old_df.groupby(['ClusterID'])['wealth'].mean().values
    df['year'] = old_df.groupby(['ClusterID'])['year.of.interview'].min().values
    df['month'] = old_df.groupby(['ClusterID'])['month.of.interview'].min().values
    df['RegionID'] = old_df.groupby(['ClusterID'])['RegionID'].min().values
    df['lat'] = old_df.groupby(['ClusterID'])['lat'].mean().values
    df['lon'] = old_df.groupby(['ClusterID'])['lon'].mean().values
    df['country'] = old_df.groupby(['ClusterID'])['country'].min().values
    df['households'] = old_df.groupby(['ClusterID'])['HouseholdID'].count().values
    return df

# %%
df = create_new_data(adels_df, df)

# %%
df.to_csv('data/aggregated_survey_data.csv')

# %%
df = df.dropna()

# %%
# Ett kd träd för varje år
# skicka in koord. en i taget och ge tillbaka cluster ID 
# filtrera bort > 10km bort

# %% [markdown]
# Create a KDtree for each year in the dataframe

# %%
available_years = df['year'].unique()
available_countries = df['country'].unique()
print(available_countries)
# Out:
# ['Angola' 'Burkina Faso' 'Benin' 'Burundi'
#  'Democratic Republic of the Congo' 'Cameroon' 'Egypt' 'Ethiopia' 'Gabon'
#  'Ghana' 'Guinea' 'Kenya' 'Liberia' 'Madagascar' 'Mali' 'Malawi'
#  'Mozambique' 'Nigeria' 'Namibia' 'Rwanda' 'Sierra Leone' 'Senegal' 'Chad'
#  'Togo' 'Uganda' 'South Africa' 'Zambia' 'Zimbabwe']

# %%
KDtrees = []
df_country = df[df['country'] == 'Angola']
df_years = []
available_years = df_country['year'].unique()

#for country in available_countries:
#df_country = df[df['country'] == country]
for year in available_years:
    df_year = df_country[df_country['year'] == year]
    df_years.append(df_year)
    #if len(df_year) != 0:
    tree = KDTree(df_year[['lat', 'lon']].values, 2)
    KDtrees.append(tree)

# %%
print(len(df_country))
print(len(df_years))
print(len(KDtrees))
# Out:
# 855
# 4
# 4

# %%
df.iloc[0]
# Out:
# index                          0
# country                   Angola
# ClusterID        AO.Bengo.71.135
# households                   127
# lat                      -8.5898
# lon                      13.6408
# wealth_pooled             52.905
# year                        2015
# month                         11
# RegionID                AO.Bengo
# Name: 0, dtype: object

# %% [markdown]
# Find the closest cluster to the cluster provided

# %%
def find_closest_coordinate_info(coordinate, tree, df):
    dist, ind = tree.query(coordinate, k=1) 
    loc = df.iloc[ind][['lat', 'lon']]
    dist_km = geodesic(coordinate, loc).km
    wealth = df.iloc[ind]['wealth_pooled']
    return dist_km, ind, wealth

# %%
df_locs = df[['lat', 'lon']].values

# %%
df_locs
# Out:
# array([[ -8.589805,  13.640789],
#        [ -7.718385,  14.122619],
#        [ -8.592545,  13.654425],
#        ...,
#        [-20.724753,  30.172833],
#        [-19.453466,  29.820084],
#        [-19.452031,  29.773865]])

# %%
dist, ind, wealth = find_closest_coordinate_info(df_locs[2], KDtrees[0], df_country)

# %%
print(dist)
print(wealth)
# Out:
# 109.58513399577286
# 29.34639874336288

# %% [markdown]
# Test so it returns same distance in kilometers

# %%
print(geodesic((-8.592545, 13.654425), (-7.71839, 14.1226)).km)
# Out:
# 109.58366020725856

# %% [markdown]
# Apply the function to each value in the dataframe

# %%
df_coord = df_country[['lat', 'lon']]

# %%
df_coord
# Out:
#           lat        lon
# 0   -8.589805  13.640789
# 1   -7.718385  14.122619
# 2   -8.592545  13.654425
# 3   -8.652260  13.517859
# 4   -7.852511  13.721998
# ..        ...        ...
# 858 -6.107200  14.628845
# 859 -6.137541  12.364993
# 860 -6.287846  13.609822
# 861 -6.136926  12.354740
# 862 -6.142472  12.359700
#
# [855 rows x 2 columns]

# %%
# Loading the lat-long data for Kolkata & Delhi 
kolkata = (22.5726, 88.3639) 
delhi = (28.7041, 77.1025) 
  
# Print the distance calculated in km 
print(geodesic(kolkata, delhi).km) 
# Distance between first and second coordinate of the cluster dataframe
print(geodesic((df_coord.iloc[0]), (df_coord.iloc[1])).km)
# Out:
# 1318.13891581683
# 110.03516543210118

# %%
i = 0
for tree in KDtrees:
    df_country['dist_year' + str(i)], df_country['index_year' + str(i)], df_country['wealth_year' + str(i)] = zip(*df_coord.apply(lambda x: find_closest_coordinate_info(x, tree, df_country), axis=1))
    i = i + 1
# Out:
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_country
# Out:
#      index country        ClusterID  households       lat        lon  \
# 0        0  Angola  AO.Bengo.71.135         127 -8.589805  13.640789
# 1        1  Angola  AO.Bengo.71.158         113 -7.718385  14.122619
# 2        2  Angola  AO.Bengo.71.169          72 -8.592545  13.654425
# 3        3  Angola  AO.Bengo.71.203         104 -8.652260  13.517859
# 4        4  Angola  AO.Bengo.71.208          95 -7.852511  13.721998
# ..     ...     ...              ...         ...       ...        ...
# 858    858  Angola   AO.Zaire.71.57         120 -6.107200  14.628845
# 859    859  Angola  AO.Zaire.71.576         116 -6.137541  12.364993
# 860    860  Angola  AO.Zaire.71.605         108 -6.287846  13.609822
# 861    861  Angola   AO.Zaire.71.71         131 -6.136926  12.354740
# 862    862  Angola   AO.Zaire.71.74          78 -6.142472  12.359700
#
#      wealth_pooled  year  month  RegionID  ... wealth_year0  dist_year1  \
# 0        52.905026  2015     11  AO.Bengo  ...    52.905026    3.105909
# 1        29.346399  2016      2  AO.Bengo  ...    48.056204  110.035165
# 2        48.056204  2015     10  AO.Bengo  ...    29.346399    2.652030
# 3        42.719684  2016      1  AO.Bengo  ...    52.905026  122.915918
# 4        30.057603  2015     11  AO.Bengo  ...    48.056204   66.995817
# ..             ...   ...    ...       ...  ...          ...         ...
# 858      37.407195  2015     11  AO.Zaire  ...    28.978510  744.443077
# 859      40.499655  2016      2  AO.Zaire  ...    17.888252  833.188477
# 860      26.631692  2016      1  AO.Zaire  ...    51.170875  752.044783
# 861      34.577817  2016      2  AO.Zaire  ...    17.888252  823.452637
# 862      37.788721  2016      2  AO.Zaire  ...    17.888252  852.819864
#
#     index_year1 wealth_year1  dist_year2 index_year2 wealth_year2  dist_year3  \
# 0            15    50.785867  455.688967          55    17.888252    0.000000
# 1             0    52.905026  131.812629          23    28.840082  110.035165
# 2            15    50.785867  455.519153          55    17.888252    1.531317
# 3             1    29.346399  447.822093          55    17.888252   15.192058
# 4            10    34.111753   46.611842           1    29.346399   82.031962
# ..          ...          ...         ...         ...          ...         ...
# 858         306    38.011581  691.042858          64    36.383966  186.757667
# 859         305    33.826806  789.972542          76    15.716124  305.595163
# 860         306    38.011581  253.848677          27    63.619402  254.603577
# 861         307    36.938927  790.794538          76    15.716124  306.178799
# 862         308    39.813563  789.971544          76    15.716124  305.381175
#
#      index_year3  wealth_year3
# 0              0     52.905026
# 1              0     52.905026
# 2              0     52.905026
# 3              0     52.905026
# 4              0     52.905026
# ..           ...           ...
# 858            1     29.346399
# 859            0     52.905026
# 860            0     52.905026
# 861            0     52.905026
# 862            0     52.905026
#
# [855 rows x 30 columns]

# %%
print('Length of df: ', len(df_country))

print(df_country['dist_year1'].where(df_country['dist_year1'] <= 10).isna().sum())
# Out:
# Length of df:  855
# 845

# %%
print(df_coord.apply(lambda x: find_closest_coordinate(x, KDtrees[1]), axis=1))
# Out:
# index:  15
# distance:  0.03175852051027566
# index:  0
# distance:  0.0
# index:  15
# distance:  0.04253491893724986
# index:  1
# distance:  0.0
# index:  10
# distance:  0.37028734825944926
# index:  109
# distance:  0.36719961405889534
# index:  2
# distance:  0.0
# index:  3
# distance:  0.0
# index:  6
# distance:  0.2768365769221998
# index:  4
# distance:  0.0
# index:  17
# distance:  0.6561337393801974
# index:  5
# distance:  0.0
# index:  15
# distance:  0.04726102822626001
# index:  6
# distance:  0.0
# index:  7
# distance:  0.0
# index:  15
# distance:  0.059585311688347575
# index:  6
# distance:  0.31763195924370297
# index:  8
# distance:  0.0
# index:  9
# distance:  0.0
# index:  15
# distance:  0.06195138462534031
# index:  10
# distance:  0.0
# index:  11
# distance:  0.0
# index:  12
# distance:  0.0
# index:  13
# distance:  0.0
# index:  14
# distance:  0.0
# index:  15
# distance:  0.0
# index:  6
# distance:  0.4406113650327116
# index:  15
# distance:  0.0391672144784019
# index:  6
# distance:  0.3045125384101738
# index:  109
# distance:  0.5163118736238979
# index:  16
# distance:  0.0
# index:  17
# distance:  0.0
# index:  18
# distance:  0.0
# index:  19
# distance:  0.0
# index:  22
# distance:  0.44325905640944013
# index:  26
# distance:  0.21877039043937713
# index:  19
# distance:  0.15217957509469981
# index:  24
# distance:  0.5751651062382003
# index:  20
# distance:  0.0
# index:  26
# distance:  0.6264958491450487
# index:  24
# distance:  0.5839546934840167
# index:  21
# distance:  0.0
# index:  24
# distance:  0.5783364268260963
# index:  24
# distance:  0.7763655250267443
# index:  24
# distance:  0.7614936879482008
# index:  22
# distance:  0.0
# index:  24
# distance:  0.6735937285641459
# index:  24
# distance:  0.7640583397077688
# index:  24
# distance:  0.9685961844535403
# index:  23
# distance:  0.0
# index:  24
# distance:  0.0
# index:  22
# distance:  0.6133881031687749
# index:  24
# distance:  0.6034066668391824
# index:  261
# distance:  0.6195379625921549
# index:  24
# distance:  0.8080826746026812
# index:  24
# distance:  0.9050458894868072
# index:  263
# distance:  1.0433381034286244
# index:  24
# distance:  0.7633399127309102
# index:  24
# distance:  0.6007780873051454
# index:  24
# distance:  0.7541200084343149
# index:  25
# distance:  0.0
# index:  22
# distance:  0.18463192045252547
# index:  26
# distance:  0.0
# index:  24
# distance:  0.7986556056830512
# index:  27
# distance:  0.0
# index:  24
# distance:  0.7376161647089634
# index:  28
# distance:  0.0
# index:  29
# distance:  0.0
# index:  30
# distance:  0.0
# index:  31
# distance:  0.0
# index:  32
# distance:  0.0
# index:  33
# distance:  0.0
# distance:  0.03242270483783648
# index:  187
# distance:  0.028526588457082693
# index:  167
# distance:  0.08965015249288327
# index:  173
# distance:  0.007583788631049698
# index:  166
# distance:  0.0
# index:  167
# distance:  0.0
# index:  181
# distance:  0.05884208413201314
# index:  168
# distance:  0.0
# index:  173
# distance:  0.04660523721642196
# index:  169
# distance:  0.0
# index:  167
# distance:  0.02585923976065571
# index:  170
# distance:  0.0
# index:  171
# distance:  0.0
# index:  172
# distance:  0.0
# index:  111
# distance:  0.2657791616699817
# index:  173
# distance:  0.0
# index:  174
# distance:  0.0
# index:  167
# distance:  0.05795123847685791
# index:  175
# distance:  0.0
# index:  176
# distance:  0.0
# index:  177
# distance:  0.0
# index:  167
# distance:  0.023779039719848186
# index:  178
# distance:  0.0
# index:  173
# distance:  0.035645652806476635
# index:  167
# distance:  0.06270536902050539
# index:  167
# distance:  0.026890822003041097
# index:  164
# distance:  0.01177961480697487
# index:  193
# distance:  0.027465146294884623
# index:  179
# distance:  0.0
# index:  164
# distance:  0.010509586100339887
# index:  180
# distance:  0.0
# index:  167
# distance:  0.04360349620154862
# index:  166
# distance:  0.012280971459911997
# index:  181
# distance:  0.0
# index:  182
# distance:  0.0
# index:  183
# distance:  0.0
# index:  167
# distance:  0.02524775405852386
# index:  167
# distance:  0.048898646780854205
# index:  167
# distance:  0.03254532834369374
# index:  184
# distance:  0.0
# index:  185
# distance:  0.0
# index:  186
# distance:  0.0
# index:  187
# distance:  0.0
# index:  188
# distance:  0.0
# index:  189
# distance:  0.0
# index:  190
# distance:  0.0
# index:  191
# distance:  0.0
# index:  192
# distance:  0.0
# index:  193
# distance:  0.0
# index:  167
# distance:  0.03804173924783349
# index:  167
# distance:  0.061005110753121324
# index:  164
# distance:  0.0036286752404166593
# index:  194
# distance:  0.0
# index:  164
# distance:  0.042684684946716546
# index:  195
# distance:  0.0
# index:  196
# distance:  0.0
# index:  197
# distance:  0.0
# index:  198
# distance:  0.0
# index:  209
# distance:  0.039042047961042776
# index:  199
# distance:  0.5722778120126961
# index:  209
# distance:  0.6372572977376567
# index:  199
# distance:  0.0
# index:  209
# distance:  0.04542334520922315
# index:  209
# distance:  0.6930827481513098
# index:  200
# distance:  0.0
# index:  201
# distance:  0.0
# index:  199
# distance:  1.0155629931388088
# index:  202
# distance:  0.0
# index:  203
# distance:  0.0
# index:  209
# distance:  0.08255588579863814
# index:  209
# distance:  0.6179517420454236
# index:  204
# distance:  0.0
# index:  209
# distance:  0.798477756850506
# index:  205
# distance:  0.0
# index:  206
# distance:  0.0
# index:  209
# distance:  0.053343672633128
# index:  209
# distance:  0.13307520505711087
# index:  207
# distance:  0.0
# index:  208
# distance:  0.0
# index:  209
# distance:  0.9997132595924427
# index:  209
# distance:  0.6505369456509601
# index:  209
# distance:  0.0
# index:  209
# distance:  0.04419285400373449
# index:  209
# distance:  0.4419949372616339
# index:  210
# distance:  0.0
# index:  209
# distance:  1.0123660164708412
# index:  211
# distance:  0.0
# index:  209
# distance:  0.05281950512829564
# index:  212
# distance:  0.0
# index:  199
# distance:  1.0226263323081641
# index:  300
# distance:  0.0
# index:  306
# distance:  0.7451410678019345
# index:  306
# distance:  0.6127184038765865
# index:  306
# distance:  0.6331875687108892
# index:  301
# distance:  0.0
# index:  306
# distance:  1.0427544166063116
# index:  306
# distance:  0.624855583182276
# index:  302
# distance:  0.0
# index:  306
# distance:  0.636480366617854
# index:  303
# distance:  0.0
# index:  306
# distance:  1.0239761793816298
# index:  304
# distance:  0.0
# index:  306
# distance:  0.6063625181729047
# index:  306
# distance:  1.0276672292007105
# index:  306
# distance:  1.0349110357151439
# index:  305
# distance:  0.0
# index:  306
# distance:  0.0
# index:  307
# distance:  0.0
# index:  308
# distance:  0.0
# 0      (0.03175852051027566, 15)
# 1                       (0.0, 0)
# 2      (0.04253491893724986, 15)
# 3                       (0.0, 1)
# 4      (0.37028734825944926, 10)
#                  ...
# 858    (1.0349110357151439, 306)
# 859                   (0.0, 305)
# 860                   (0.0, 306)
# 861                   (0.0, 307)
# 862                   (0.0, 308)
# Length: 863, dtype: object

# %%
# plot the largest clusters
geoplot.plot_locs(df_coord, figsize=(4, 4), title=title)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-0d07ab8c4fbd> in <module>
#       1 # plot the largest clusters
# ----> 2 geoplot.plot_locs(df_coord, figsize=(4, 4), title=title)
#       3
#       4 plt.show()
#
# AttributeError: module 'geoplot' has no attribute 'plot_locs'

# %% [markdown]
# Plot showing how asset wealth index is changed over time

# %%
fig, ax = plt.subplots()
for country in clusters_df['country'].unique():
    country_df = clusters_df[clusters_df['country'] == country]
    country_by_year = country_df.groupby(['year']).mean()
    country_by_year['wealthpooled'].plot(kind='line', ax=ax)
    ax.legend(clusters_df['country'].unique(), loc=0, bbox_to_anchor=(1.1, 1.35));
plt.title('Asset wealth index change over time');

# %%
cool_df = clusters_df.groupby(['country', 'year']).mean()

# %%
cool_df['wealthpooled']
# Out:
# country                       year
# angola                        2011    0.122215
#                               2015    0.270364
# benin                         2012    0.200553
# burkina_faso                  2010   -0.146392
#                               2014   -0.034780
# cameroon                      2011    0.297327
# cote_d_ivoire                 2012    0.477785
# democratic_republic_of_congo  2013   -0.506605
# ethiopia                      2010   -0.450725
# ghana                         2014    0.855409
#                               2016    0.804072
# guinea                        2012    0.101090
# kenya                         2014    0.061579
#                               2015    0.261875
# lesotho                       2009   -0.121158
#                               2014    0.267961
# malawi                        2010   -0.437852
#                               2012   -0.261324
#                               2014   -0.164519
#                               2015   -0.188475
# mali                          2012    0.232781
#                               2015    0.403508
# mozambique                    2009   -0.216493
#                               2011    0.020327
# nigeria                       2010    0.351732
#                               2013    0.562958
#                               2015    0.668510
# rwanda                        2010   -0.481522
#                               2014   -0.205886
# senegal                       2010    0.354166
#                               2012    0.536270
# sierra_leone                  2013   -0.159722
# tanzania                      2010   -0.317913
#                               2011   -0.169164
#                               2015    0.083035
# togo                          2013    0.313965
# uganda                        2009   -0.391447
#                               2011   -0.232555
#                               2014   -0.176288
# zambia                        2013    0.108498
# zimbabwe                      2010    0.374875
#                               2015    0.654183
# Name: wealthpooled, dtype: float64

# %%
angola_df = clusters_df[clusters_df['country'] == 'angola']
angola_2011 = angola_df[angola_df['year'] == 2011]
angola_2015 = angola_df[angola_df['year'] == 2015]
# mean per country per year

# %%
# Out:
#                                          lat        lon  wealthpooled  \
# country                      year
# angola                       2011 -10.891445  15.189450      0.122215
#                              2015 -10.718080  15.586064      0.270364
# benin                        2012   7.757650   2.237945      0.200553
# burkina_faso                 2010  12.221145  -1.909577     -0.146392
#                              2014  12.161003  -1.919876     -0.034780
# cameroon                     2011   5.744451  11.667186      0.297327
# cote_d_ivoire                2012   7.010525  -5.222275      0.477785
# democratic_republic_of_congo 2013  -3.268139  22.682453     -0.506605
# ethiopia                     2010   9.661990  38.718503     -0.450725
# ghana                        2014   7.215853  -1.071828      0.855409
#                              2016   7.189403  -1.106107      0.804072
# guinea                       2012  10.267359 -11.816209      0.101090
# kenya                        2014  -0.404252  36.740044      0.061579
#                              2015  -0.567354  36.755563      0.261875
# lesotho                      2009 -29.524140  28.061915     -0.121158
#                              2014 -29.524077  28.052569      0.267961
# malawi                       2010 -14.123835  34.495702     -0.437852
#                              2012 -14.176805  34.462321     -0.261324
#                              2014 -13.653414  34.301566     -0.164519
#                              2015 -14.102016  34.517602     -0.188475
# mali                         2012  13.164266  -6.992970      0.232781
#                              2015  13.220496  -6.852854      0.403508
# mozambique                   2009 -19.126102  35.418111     -0.216493
#                              2011 -19.437539  35.214767      0.020327
# nigeria                      2010   8.294328   7.444367      0.351732
#                              2013   8.494743   7.305336      0.562958
#                              2015   8.429556   7.246627      0.668510
# rwanda                       2010  -2.008512  29.853829     -0.481522
#                              2014  -2.011523  29.860766     -0.205886
# senegal                      2010  14.261869 -15.478897      0.354166
#                              2012  14.282484 -15.507172      0.536270
# sierra_leone                 2013   8.396463 -12.018036     -0.159722
# tanzania                     2010  -5.833589  36.210667     -0.317913
#                              2011  -5.855345  35.718247     -0.169164
#                              2015  -5.828013  35.694310      0.083035
# togo                         2013   7.934778   1.021594      0.313965
# uganda                       2009   1.030291  32.323541     -0.391447
#                              2011   1.085648  32.330496     -0.232555
#                              2014   1.199302  32.467925     -0.176288
# zambia                       2013 -13.195091  28.624393      0.108498
# zimbabwe                     2010 -18.886674  30.301592      0.374875
#                              2015 -18.862497  30.319630      0.654183
#
#                                    households  urban_rural
# country                      year
# angola                       2011   33.669565     0.404348
#                              2015   24.091200     0.552000
# benin                        2012   23.197051     0.415550
# burkina_faso                 2010   24.992606     0.316081
#                              2014   25.056452     0.209677
# cameroon                     2011   24.149306     0.510417
# cote_d_ivoire                2012   26.689150     0.469208
# democratic_republic_of_congo 2013   33.605691     0.321138
# ethiopia                     2010   27.761821     0.285464
# ghana                        2014   27.436019     0.511848
#                              2016   28.833333     0.500000
# guinea                       2012   23.533333     0.356667
# kenya                        2014   22.555836     0.388013
#                              2015   26.306122     0.469388
# lesotho                      2009   23.205063     0.237975
#                              2014   23.335840     0.295739
# malawi                       2010   29.111245     0.182588
#                              2012   24.300000     0.314286
#                              2014   24.307143     0.357143
#                              2015   30.952941     0.203529
# mali                         2012   24.418886     0.280872
#                              2015   23.949153     0.254237
# mozambique                   2009   22.355556     0.451852
#                              2011   22.725780     0.418719
# nigeria                      2010   24.564854     0.338912
#                              2013   42.780652     0.415073
#                              2015   23.692547     0.422360
# rwanda                       2010   25.357724     0.160569
#                              2014   25.658537     0.229675
# senegal                      2010   20.174026     0.381818
#                              2012   20.860000     0.395000
# sierra_leone                 2013   28.818391     0.363218
# tanzania                     2010   20.192140     0.240175
#                              2011   17.129145     0.232112
#                              2015   20.557566     0.296053
# togo                         2013   28.539394     0.387879
# uganda                       2009   25.941176     0.152941
#                              2011   22.245000     0.297500
#                              2014   24.360577     0.201923
# zambia                       2013   21.730181     0.424200
# zimbabwe                     2010   23.877863     0.419847
#                              2015   26.042500     0.415000

# %%
angola_2011['wealthpooled'].mean()
# Out:
# 0.1222153641445484

# %%
angola_2015['wealthpooled'].mean()
# Out:
# 0.27036411802433424

# %%
#!pip install geopandas

# %%
#!pip install contextily

# %%
#!pip install geovoronoi

# %%
#!pip install cartopy

# %%
#!pip install geoplot

# %%
#!pip install geovoronoi

# %%
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
from shapely.ops import cascaded_union
from geovoronoi.plotting import subplot_for_map, plot_voronoi_polys_with_points_in_area
from geovoronoi import voronoi_regions_from_coords, points_to_coords
import geoplot
import geoplot.crs as gcrs
# Out:
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
import warnings; 
warnings.filterwarnings('ignore', 'GeoSeries.isna', UserWarning)

# %%
from shapely.geometry import Point

# %%
clusters_df.lat[1]
# Out:
# -12.360864999999999

# %%
world = gpd.read_file(
    gpd.datasets.get_path('naturalearth_lowres')
)
africa = world.query('continent == "Africa"')
#ax = geoplot.cartogram(
#    africa, scale='pop_est', limits=(0.2, 1),
#    edgecolor='None', figsize=(7, 8)
#)


#points = Point(clusters_df.lat[1], clusters_df.lon[1])

geometry = [Point(xy) for xy in zip(clusters_df.lon, clusters_df.lat)]
gdf = gpd.GeoDataFrame(clusters_df, geometry=geometry)

# Set the map projection
proj = geoplot.crs.Mercator()

# Setup the Voronoi axes; this creates the Voronoi regions
ax = geoplot.voronoi(gdf,  # Define the GeoPandas DataFrame
                     hue='wealthpooled',  # df column used to color regions
                     clip=africa,  # Define the voronoi clipping (map edge)
                     projection=proj,  # Define the Projection
                     cmap='Reds',  # color seed
                     legend=True, # Create a legend
                     edgecolor='white',  # Color of the voronoi boundaries
                     linewidth=0.01  # width of the voronoi boundary lines
)

#geoplot.polyplot(africa, edgecolor='gray', facecolor='lightgray')
# Out:
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fb675a07170> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     477         self._done_img_factory = True
#     478
# --> 479         return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
#     480
#     481     def _update_title_position(self, renderer):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/feature_artist.py in draw(self, renderer, *args, **kwargs)
#     150         extent = None
#     151         try:
# --> 152             extent = ax.get_extent(feature_crs)
#     153         except ValueError:
#     154             warnings.warn('Unable to determine extent. Defaulting to global.')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in get_extent(self, crs)
#     728
#     729         """
# --> 730         p = self._get_extent_geom(crs)
#     731         r = p.bounds
#     732         x1, y1, x2, y2 = r
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in _get_extent_geom(self, crs)
#     774                 domain_in_src_proj)
#     775             geom_in_crs = proj.project_geometry(geom_in_src_proj,
# --> 776                                                 self.projection)
#     777         else:
#     778             geom_in_crs = boundary_poly.intersection(domain_in_src_proj)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cartopy/crs.py in project_geometry(self, geometry, src_crs)
#     216             raise ValueError('Unsupported geometry '
#     217                              'type {!r}'.format(geom_type))
# --> 218         return getattr(self, method_name)(geometry, src_crs)
#     219
#     220     def _project_point(self, point, src_crs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cartopy/crs.py in _project_polygon(self, polygon, src_crs)
#     358         rings = []
#     359         multi_lines = []
# --> 360         for src_ring in [polygon.exterior] + list(polygon.interiors):
#     361             p_rings, p_mline = self._project_linear_ring(src_ring, src_crs)
#     362             if p_rings:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/shapely/geometry/polygon.py in exterior(self)
#     254             g = lgeos.GEOSGetExteriorRing(self._geom)
#     255             ring = LinearRing()
# --> 256             ring._geom = g
#     257             ring.__p__ = self
#     258             ring._other_owned = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/shapely/geometry/base.py in _geom(self, val)
#     265     @_geom.setter
#     266     def _geom(self, val):
# --> 267         self.empty()
#     268         self._is_empty = val in [EMPTY, None]
#     269         self.__geom__ = val
#
# ~/opt/anaconda3/lib/python3.7/site-packages/shapely/geometry/base.py in empty(self, val)
#     230                 log.exception("Failed to delete GEOS geom")
#     231
# --> 232         self._is_empty = True
#     233         self.__geom__ = val
#     234
#
# KeyboardInterrupt:

# %%
world = gpd.read_file(
    gpd.datasets.get_path('naturalearth_lowres')
)
africa = world.query('continent == "Africa"')
#ax = geoplot.cartogram(
#    africa, scale='pop_est', limits=(0.2, 1),
#    edgecolor='None', figsize=(7, 8)
#)

africa = africa.cx[:, 3:0]

geometry = [Point(xy) for xy in zip(clusters_df.lon, clusters_df.lat)]
gdf = gpd.GeoDataFrame(clusters_df, geometry=geometry)

# Set the map projection
proj = geoplot.crs.Mercator()

# Setup the Voronoi axes; this creates the Voronoi regions
ax = geoplot.voronoi(gdf,  # Define the GeoPandas DataFrame
                     hue='wealthpooled',  # df column used to color regions
                     clip=africa,  # Define the voronoi clipping (map edge)
                     projection=proj,  # Define the Projection
                     cmap='Reds',  # color seed
                     legend=True, # Create a legend
                     edgecolor='white',  # Color of the voronoi boundaries
                     linewidth=0.01  # width of the voronoi boundary lines
)

#geoplot.polyplot(africa, edgecolor='gray', facecolor='lightgray')
# Out:
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/geopandas/geodataframe.py:852: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")

# %% [markdown]
# Plot each survey location on the map of Africa

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from descartes import PolygonPatch

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

def plotCountryPatch( axes, country_name, fcolor ):
    # plot a country on the provided axes
    nami = world[world.name == country_name]
    namigm = nami.__geo_interface__['features']  # geopandas's geo_interface
    namig0 = {'type': namigm[0]['geometry']['type'], \
              'coordinates': namigm[0]['geometry']['coordinates']}
    axes.add_patch(PolygonPatch( namig0, fc=fcolor, ec="black", alpha=0.85, zorder=2 ))

# plot the whole world
#ax2 = world.plot( figsize=(8,4), edgecolor=u'gray', cmap='Set2' )

proj = geoplot.crs.Mercator()

# or plot Africa continent
ax2 = world[world.continent == 'Africa'].plot(figsize=(8,8), edgecolor=u'gray', color='white')#cmap='magma')

# then plot some countries on top
#plotCountryPatch(ax2, 'Namibia', 'red')
#plotCountryPatch(ax2, 'Libya', 'green')

geometry = [Point(xy) for xy in zip(clusters_df.lon, clusters_df.lat)]
gdf = gpd.GeoDataFrame(clusters_df, geometry=geometry)

gdf.plot(ax=ax2, color='red', markersize=0.5, legend=True)


# the place to plot additional vector data (points, lines)

plt.ylabel('Latitude')
plt.xlabel('Longitude')

plt.title('Location of survey data')
#ax2.axis('scaled')
plt.show()

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from descartes import PolygonPatch

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

def plotCountryPatch( axes, country_name, fcolor ):
    # plot a country on the provided axes
    nami = world[world.name == country_name]
    namigm = nami.__geo_interface__['features']  # geopandas's geo_interface
    namig0 = {'type': namigm[0]['geometry']['type'], \
              'coordinates': namigm[0]['geometry']['coordinates']}
    axes.add_patch(PolygonPatch( namig0, fc=fcolor, ec="black", alpha=0.85, zorder=2 ))

# plot the whole world
#ax2 = world.plot( figsize=(8,4), edgecolor=u'gray', cmap='Set2' )

proj = geoplot.crs.Mercator()

# or plot Africa continent
ax2 = world[world.continent == 'Africa'].plot(figsize=(8,8), edgecolor=u'gray', color='white')#cmap='magma')

# then plot some countries on top
#plotCountryPatch(ax2, 'Namibia', 'red')
#plotCountryPatch(ax2, 'Libya', 'green')
geometry = [Point(xy) for xy in zip(df.lon, df.lat)]
gdf = gpd.GeoDataFrame(df, geometry=geometry)

gdf.plot(ax=ax2, color='red', markersize=0.5, legend=True)


# the place to plot additional vector data (points, lines)

plt.ylabel('Latitude')
plt.xlabel('Longitude')

plt.title('Location of ADELS survey data')
#ax2.axis('scaled')
plt.show()

# %% [markdown]
# Plot the number of surveys on the map

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# plot the whole world
#ax2 = world.plot( figsize=(8,4), edgecolor=u'gray', cmap='Set2' )

proj = geoplot.crs.Mercator()

# or plot Africa continent
ax2 = world[world.continent == 'Africa'].plot(figsize=(8,8), edgecolor=u'gray', color='white')#cmap='magma')

# then plot some countries on top
#plotCountryPatch(ax2, 'Namibia', 'red')
#plotCountryPatch(ax2, 'Libya', 'green')

urban_df = clusters_df[clusters_df['urban_rural'] == 1]

geometry = [Point(xy) for xy in zip(urban_df.lon, urban_df.lat)]
gdf = gpd.GeoDataFrame(urban_df, geometry=geometry)

gdf.plot(ax=ax2, color='red', markersize=0.5, legend=True)

rural_df = clusters_df[clusters_df['urban_rural'] == 0]

geometry = [Point(xy) for xy in zip(rural_df.lon, rural_df.lat)]
gdf = gpd.GeoDataFrame(rural_df, geometry=geometry)

gdf.plot(ax=ax2, color='blue', markersize=0.5, legend=True)



# the place to plot additional vector data (points, lines)

plt.ylabel('Latitude')
plt.xlabel('Longitude')

plt.title('Location of survey data')
#ax2.axis('scaled')
plt.show()

# %%
clusters_df['urban_rural'].hist()

# %%
import mapclassify
wealth = clusters_df['wealthpooled']
scheme = mapclassify.Quantiles(wealth, k=5)

# Note: this code sample requires geoplot>=0.4.0.
geoplot.choropleth(
    africa, hue=wealth, scheme=scheme,
    cmap='Greens', figsize=(8, 4)
)

# %%
n_households = clusters_df['households']
scheme = mapclassify.Quantiles(n_households, k=25)

# Note: this code sample requires geoplot>=0.4.0.
geoplot.choropleth(
    africa, hue=n_households, scheme=scheme,
    cmap='Greens', figsize=(8, 4)
)
# Out:
# /Users/juliaortheden/opt/anaconda3/lib/python3.7/site-packages/mapclassify/classifiers.py:237: UserWarning: Warning: setting k to 17
#   Warn("Warning: setting k to %d" % k_q, UserWarning)

# %%
clusters_df['year'].hist()

# %%
clusters_df[clusters_df['country']=='angola']['year']
# Out:
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
#        ...
# 850    2015
# 851    2015
# 852    2015
# 853    2015
# 854    2015
# Name: year, Length: 855, dtype: int64

# %%
ghana_df = clusters_df[clusters_df['country']=='ghana']

# %%
ghana_2016_df = ghana_df[ghana_df['year']==2016]

# %%
ghana_2014_df = ghana_df[ghana_df['year']==2014]

# %%
ghana_2016_df
# Out:
#      country  year        lat       lon   GID_1      GID_2  wealthpooled  \
# 4792   ghana  2016   5.076585 -2.887155  GHA.10   GHA.10.5      0.704634
# 4793   ghana  2016   5.286215 -2.763417  GHA.10   GHA.10.5      1.390819
# 4794   ghana  2016   4.916464 -2.174210  GHA.10   GHA.10.8      0.731194
# 4795   ghana  2016   4.914636 -1.781184  GHA.10  GHA.10.10      1.807246
# 4796   ghana  2016   4.924901 -1.753950  GHA.10  GHA.10.10      1.422209
# ...      ...   ...        ...       ...     ...        ...           ...
# 4979   ghana  2016  10.947258 -2.168228   GHA.8    GHA.8.5      0.061642
# 4980   ghana  2016  10.917617 -2.655202   GHA.8    GHA.8.1     -0.223815
# 4981   ghana  2016  10.641916 -2.759454   GHA.8    GHA.8.2     -0.136469
# 4982   ghana  2016  10.640043 -2.882381   GHA.8    GHA.8.2      0.834113
# 4983   ghana  2016  10.420661 -2.551337   GHA.8    GHA.8.3      0.257282
#
#       households  urban_rural                   geometry
# 4792          30            0   POINT (-2.88715 5.07658)
# 4793          29            1   POINT (-2.76342 5.28622)
# 4794          29            0   POINT (-2.17421 4.91646)
# 4795          29            1   POINT (-1.78118 4.91464)
# 4796          29            1   POINT (-1.75395 4.92490)
# ...          ...          ...                        ...
# 4979          29            0  POINT (-2.16823 10.94726)
# 4980          30            0  POINT (-2.65520 10.91762)
# 4981          30            0  POINT (-2.75945 10.64192)
# 4982          30            1  POINT (-2.88238 10.64004)
# 4983          30            0  POINT (-2.55134 10.42066)
#
# [192 rows x 10 columns]

# %%
ghana_2014_df
# Out:
#      country  year        lat       lon  GID_1     GID_2  wealthpooled  \
# 4370   ghana  2014   5.793782 -0.400936  GHA.4   GHA.4.3      0.536396
# 4371   ghana  2014   6.742562 -1.636748  GHA.1  GHA.1.16      1.826202
# 4372   ghana  2014   5.503744 -0.413996  GHA.3   GHA.3.7      1.414853
# 4373   ghana  2014  10.554068  0.038188  GHA.6   GHA.6.2     -0.170658
# 4374   ghana  2014   6.725353 -1.586704  GHA.1  GHA.1.16      1.751851
# ...      ...   ...        ...       ...    ...       ...           ...
# 4787   ghana  2014   6.493993 -0.952127  GHA.4   GHA.4.6      0.829967
# 4788   ghana  2014   6.896419  0.513165  GHA.9   GHA.9.3      1.112039
# 4789   ghana  2014   6.653406 -1.585132  GHA.1  GHA.1.16      1.536749
# 4790   ghana  2014  10.056925 -2.484954  GHA.8   GHA.8.6      1.325197
# 4791   ghana  2014   5.907477 -1.045247  GHA.4   GHA.4.7      0.330901
#
#       households  urban_rural                   geometry
# 4370          30            0   POINT (-0.40094 5.79378)
# 4371          26            1   POINT (-1.63675 6.74256)
# 4372          25            1   POINT (-0.41400 5.50374)
# 4373          30            0   POINT (0.03819 10.55407)
# 4374          28            1   POINT (-1.58670 6.72535)
# ...          ...          ...                        ...
# 4787          28            0   POINT (-0.95213 6.49399)
# 4788          26            0    POINT (0.51316 6.89642)
# 4789          30            1   POINT (-1.58513 6.65341)
# 4790          27            1  POINT (-2.48495 10.05692)
# 4791          28            1   POINT (-1.04525 5.90748)
#
# [422 rows x 10 columns]

# %%
ghana_2014_df = ghana_2014_df.reset_index()

# %%
ghana_2016_df = ghana_2016_df.reset_index()

# %%
def find_closest_point(point, point_list):
    min_dist = 10000
    min_point = None
    for neighbor in point_list:
        neighbor_dist = point.distance(neighbor)
        if  neighbor_dist < min_dist:
            min_point = neighbor
            min_dist = neighbor_dist
    return min_point

# %%
def get_wealth_diff(df_2014, df_2016):
    wealth_diff_list = []
    for point in df_2014['geometry']:
        closest_point = find_closest_point(point, df_2016['geometry'])
        closest_point_wealth = df_2016[df_2016['geometry'] == closest_point]['wealthpooled']
        point_wealth = df_2014[df_2014['geometry'] == point]['wealthpooled']
        wealth_difference = closest_point_wealth.item() - point_wealth.item()
        wealth_diff_list.append(wealth_difference)
    return wealth_diff_list

# %%
wealth_list = get_wealth_diff(ghana_2014_df, ghana_2016_df)

# %%
np.array(wealth_list).mean()
# Out:
# -0.0036304596289043396

# %% [markdown]
# Try similar thing for Angola between 2011 and 2015

# %%
angola_df = clusters_df[clusters_df['country']=='angola']

# %%
angola_2015_df = angola_df[angola_df['year']==2015]

# %%
angola_2011_df = angola_df[angola_df['year']==2011]

# %%
wealth_list = get_wealth_diff(angola_2011_df, angola_2015_df)

# %%
np.array(wealth_list).mean()
# Out:
# 0.40163195196174734
